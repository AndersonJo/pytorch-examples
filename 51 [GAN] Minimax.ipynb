# %%
# %pylab inline
import numpy as np
import torch

from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.autograd import Variable
from torch.utils.data import dataloader

from torchvision import transforms
from torchvision.datasets import MNIST
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Configuration

# %%
BATCH_SIZE = 32

# %% [markdown]
# ## Data (MNIST)

# %%
train = MNIST('./data', train=True, download=True, transform=transforms.Compose([
    transforms.ToTensor(), # ToTensor does min-max normalization. 
]), )

test = MNIST('./data', train=False, download=True, transform=transforms.Compose([
    transforms.ToTensor(), # ToTensor does min-max normalization. 
    
]), )

# Create DataLoader
dataloader_args = dict(shuffle=True, batch_size=BATCH_SIZE ,num_workers=1, pin_memory=True)
train_loader = dataloader.DataLoader(train, **dataloader_args)
test_loader = dataloader.DataLoader(test, **dataloader_args)

# %% [markdown]
# ## Model Discriminator
#
# ### Discriminator
#
# * $ x_i \sim P_{\rm data} $ (즉 true data distribution) 에서 왔다면 1
# * $ x_i = G(z) $ 이때 $ z \sim p_{\rm generator} $ (generators' distribution)에서 왔다면 0
#
# 즉 Discriminator는 "이 사진이 진짜냐? (가짜가 아니고)" 라고 질문하는 것

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.fc1 = nn.Linear(784, 548)
        self.fc2 = nn.Linear(548, 252)
        self.fc3 = nn.Linear(252, 1)
        
        self.bc1 = nn.BatchNorm1d(548)
        self.bc2 = nn.BatchNorm1d(252)
                
    def forward(self, x):
        x = x.view((-1, 784))
        h = self.fc1(x)
        h = self.bc1(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.5, training=self.training)
        
        h = self.fc2(h)
        h = self.bc2(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.2, training=self.training)
        
        h = self.fc3(h)
        out = F.sigmoid(h)
        return out

D = Discriminator()
print(D.cuda()) # CUDA!
d_optimizer = optim.Adam(D.parameters(), lr=0.001)
# Out:
# Discriminator (
#   (fc1): Linear (784 -> 548)
#   (fc2): Linear (548 -> 252)
#   (fc3): Linear (252 -> 1)
#   (bc1): BatchNorm1d(548, eps=1e-05, momentum=0.1, affine=True)
#   (bc2): BatchNorm1d(252, eps=1e-05, momentum=0.1, affine=True)
# )

# %% [markdown]
# ### Generator

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        
        self.fc1 = nn.Linear(100, 196)
        self.fc2 = nn.Linear(196, 289)
        self.fc3 = nn.Linear(289, 361)
        self.fc4 = nn.Linear(361, 529)
        self.fc5 = nn.Linear(529, 784)
        
        self.bc1 = nn.BatchNorm1d(196)
        self.bc2 = nn.BatchNorm1d(289)
        self.bc3 = nn.BatchNorm1d(361)
        self.bc4 = nn.BatchNorm1d(529)
    
    def forward(self, x):
        h = self.fc1(x)
        h = self.bc1(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.5, training=self.training)
        
        h = self.fc2(h)
        h = self.bc2(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.3, training=self.training)
        
        h = self.fc3(h)
        h = self.bc3(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.2, training=self.training)
        
        h = self.fc4(h)
        h = self.bc4(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.2, training=self.training)
        
        h = self.fc5(h)
        out = F.sigmoid(h)
        return out

G = Generator()
print(G.cuda())
g_optimizer = optim.Adam(G.parameters(), lr=0.001)
# Out:
# Generator (
#   (fc1): Linear (100 -> 196)
#   (fc2): Linear (196 -> 289)
#   (fc3): Linear (289 -> 361)
#   (fc4): Linear (361 -> 529)
#   (fc5): Linear (529 -> 784)
#   (bc1): BatchNorm1d(196, eps=1e-05, momentum=0.1, affine=True)
#   (bc2): BatchNorm1d(289, eps=1e-05, momentum=0.1, affine=True)
#   (bc3): BatchNorm1d(361, eps=1e-05, momentum=0.1, affine=True)
#   (bc4): BatchNorm1d(529, eps=1e-05, momentum=0.1, affine=True)
# )

# %% [markdown]
# ## Train
#
# * $ 1 $ : real images
# * $ 0 $ : fake images

# %%
N_EPOCH = 30

real_y = Variable(torch.ones((BATCH_SIZE, 1)).cuda())
fake_y = Variable(torch.zeros((BATCH_SIZE, 1)).cuda())
loss_f = nn.BCELoss()

d_real_losses = list()
d_fake_losses = list()
g_losses = list()

# %%
# Train Discriminator with Generator not being trained
# 먼저 Discriminator를 학습시킵니다.
# 이때 real image와 fake이미지 두개의 데이터를 사용하여 학습합니다. 
# Discriminator를 학습시킬때는 Generator는 학습시키면 안됩니다.

for epoch in range(N_EPOCH):
    _d_real_losses = list()
    _d_fake_losses = list()
    _g_losses = list()
    
    
    for step, (real_images, _) in enumerate(train_loader):
        real_images = Variable(real_images.cuda())

        # Init D
        d_optimizer.zero_grad()

        ###############################################
        # Train D with real images
        ###############################################
        y_real_pred = D(real_images)
        d_real_loss = loss_f(y_real_pred, real_y)
        d_real_loss.backward()
        d_optimizer.step()
        
        # Visualization
        _d_real_losses.append(d_real_loss.data[0])

        ###############################################
        # Train D with fake images but do not train G
        ###############################################
        fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
        fake_images = G(fake_distributions).detach()
        y_pred = D(fake_images)
        d_fake_loss = loss_f(y_pred, fake_y)
        d_fake_loss.backward()
        d_optimizer.step()
        
        # Visualization
        _d_fake_losses.append(d_fake_loss.data[0])

        ###############################################
        # Train G with fake images but do not train G
        ###############################################
        g_optimizer.zero_grad()
        
        fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
        fake_images = G(fake_distributions)
        y_pred = D(fake_images)
        g_loss = loss_f(y_pred, fake_y)
        g_loss.backward()
        g_optimizer.step()
        
        # Visualization
        _g_losses.append(g_loss.data.cpu().numpy()[0])
        
        if step % 100 == 0:
            _d_real_losses = np.array(_d_real_losses)
            _d_fake_losses = np.array(_d_fake_losses)
            _g_losses = np.array(_g_losses)
            
            d_real_losses.append(_d_real_losses.mean())
            d_fake_losses.append(_d_fake_losses.mean())
            g_losses.append(_g_losses.mean())
            
            _d_real_losses = list()
            _d_fake_losses = list()
            _g_losses = list()
            
            print(f'\rEpoch:[{epoch}] Step:[{step}] -',
                  '[D_real_loss]: {:.4}'.format(d_real_loss.data[0]),
                  '[D_fake_loss]: {:.4}'.format(d_fake_loss.data[0]), 
                  '[G_loss]:{:.4}'.format(g_loss.data[0]), end='') 
    print()
# Out:
# Epoch:[0] Step:[1800] - [D_real_loss]: 0.0005922 [D_fake_loss]: 0.002187 [G_loss]:0.003558
# Epoch:[1] Step:[1800] - [D_real_loss]: 2.056e-05 [D_fake_loss]: 0.0004589 [G_loss]:0.0002277
# Epoch:[2] Step:[1800] - [D_real_loss]: 2.76e-06 [D_fake_loss]: 4.995e-05 [G_loss]:4.213e-055
# Epoch:[3] Step:[1800] - [D_real_loss]: 3.222e-05 [D_fake_loss]: 8.85e-05 [G_loss]:0.00047345
# Epoch:[4] Step:[1800] - [D_real_loss]: 0.001049 [D_fake_loss]: 5.679e-05 [G_loss]:4.493e-055
# Epoch:[5] Step:[1800] - [D_real_loss]: 9.202e-07 [D_fake_loss]: 0.0002676 [G_loss]:0.0001817
# Epoch:[6] Step:[1800] - [D_real_loss]: 1.498e-06 [D_fake_loss]: 0.008009 [G_loss]:0.00041958
# Epoch:[7] Step:[1800] - [D_real_loss]: 1.993e-06 [D_fake_loss]: 1.48e-05 [G_loss]:3.823e-055
# Epoch:[8] Step:[1800] - [D_real_loss]: 8.196e-08 [D_fake_loss]: 1.536e-05 [G_loss]:0.0001694
# Epoch:[9] Step:[1800] - [D_real_loss]: 4.023e-07 [D_fake_loss]: 1.777e-05 [G_loss]:3.895e-06
# Epoch:[10] Step:[1800] - [D_real_loss]: 0.0 [D_fake_loss]: 6.19e-06 [G_loss]:2.427e-05558e-05
# Epoch:[11] Step:[1800] - [D_real_loss]: 0.0 [D_fake_loss]: 1.039e-05 [G_loss]:8.026e-0607e-05
# Epoch:[12] Step:[1800] - [D_real_loss]: 9.947e-07 [D_fake_loss]: 1.695e-05 [G_loss]:3.149e-05
# Epoch:[13] Step:[1800] - [D_real_loss]: 0.0 [D_fake_loss]: 1.154e-05 [G_loss]:0.00042745e-056
# Epoch:[14] Step:[1800] - [D_real_loss]: 2.559e-06 [D_fake_loss]: 1.495e-05 [G_loss]:1.208e-05
# Epoch:[15] Step:[1800] - [D_real_loss]: 1.427e-06 [D_fake_loss]: 0.0001116 [G_loss]:2.227e-05
# Epoch:[16] Step:[1800] - [D_real_loss]: 1.177e-06 [D_fake_loss]: 1.716e-05 [G_loss]:6.644e-06
# Epoch:[17] Step:[1800] - [D_real_loss]: 3.725e-09 [D_fake_loss]: 4.043e-05 [G_loss]:4.269e-05
# Epoch:[18] Step:[1800] - [D_real_loss]: 5.212e-06 [D_fake_loss]: 1.086e-05 [G_loss]:3.479e-05
# Epoch:[19] Step:[1800] - [D_real_loss]: 1.118e-08 [D_fake_loss]: 2.115e-05 [G_loss]:4.116e-05
# Epoch:[20] Step:[1800] - [D_real_loss]: 0.0 [D_fake_loss]: 9.336e-06 [G_loss]:4.125e-0593e-05
# Epoch:[21] Step:[1800] - [D_real_loss]: 0.0 [D_fake_loss]: 1.919e-06 [G_loss]:1.85e-05629e-06
# Epoch:[22] Step:[1800] - [D_real_loss]: 7.451e-09 [D_fake_loss]: 1.956e-07 [G_loss]:1.509e-07
# Epoch:[23] Step:[1800] - [D_real_loss]: 3.725e-08 [D_fake_loss]: 8.88e-05 [G_loss]:2.608e-066
# Epoch:[24] Step:[1800] - [D_real_loss]: 0.0 [D_fake_loss]: 7.059e-07 [G_loss]:3.187e-0601e-06
# Epoch:[25] Step:[1800] - [D_real_loss]: 0.0 [D_fake_loss]: 1.003e-05 [G_loss]:7.879e-0724e-06
# Epoch:[26] Step:[1800] - [D_real_loss]: 0.0 [D_fake_loss]: 7.451e-07 [G_loss]:2.094e-05-07-06
# Epoch:[27] Step:[1800] - [D_real_loss]: 0.0 [D_fake_loss]: 7.4e-05 [G_loss]:5.962e-0576060505
# Epoch:[28] Step:[1800] - [D_real_loss]: 4.545e-07 [D_fake_loss]: 3.355e-05 [G_loss]:1.816e-05
# Epoch:[29] Step:[1800] - [D_real_loss]: 0.0 [D_fake_loss]: 1.863e-06 [G_loss]:6.948e-062e-065

# %% [markdown]
# ## Loss Visualization

# %%
plot(d_real_losses, label='D(x) Loss')
plot(d_fake_losses, label='D(G(z)) Loss')
plot(g_losses, label='G(z) loss')
yscale('log')
grid()
legend()

# %%
fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
images = G(fake_distributions).view((-1, 28, 28)).data.cpu().numpy()

images[0]
imshow(images[0], cmap=cm.gray_r)

fig, subplots = pylab.subplots(4, 5) # subplots(y축, x축 갯수)

idx = 10
for _subs in subplots:
    for subplot in _subs:
        d = images[idx]
        subplot.get_xaxis().set_visible(False)
        subplot.get_yaxis().set_visible(False)
        subplot.imshow(d, cmap=cm.gray_r)
        idx += 1
