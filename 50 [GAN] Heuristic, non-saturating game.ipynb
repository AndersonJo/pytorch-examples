# %%
# %pylab inline
import numpy as np
import torch

from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.autograd import Variable
from torch.utils.data import dataloader

from torchvision import transforms
from torchvision.datasets import MNIST
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Configuration

# %%
BATCH_SIZE = 32

# %% [markdown]
# ## Data (MNIST)

# %%
train = MNIST('./data', train=True, download=True, transform=transforms.Compose([
    transforms.ToTensor(), # ToTensor does min-max normalization. 
]), )

test = MNIST('./data', train=False, download=True, transform=transforms.Compose([
    transforms.ToTensor(), # ToTensor does min-max normalization. 
    
]), )

# Create DataLoader
dataloader_args = dict(shuffle=True, batch_size=BATCH_SIZE ,num_workers=1, pin_memory=True)
train_loader = dataloader.DataLoader(train, **dataloader_args)
test_loader = dataloader.DataLoader(test, **dataloader_args)

# %% [markdown]
# ## Model Discriminator
#
# ### Discriminator
#
# * $ x_i \sim P_{\rm data} $ (즉 true data distribution) 에서 왔다면 1
# * $ x_i = G(z) $ 이때 $ z \sim p_{\rm generator} $ (generators' distribution)에서 왔다면 0
#
# 즉 Discriminator는 "이 사진이 진짜냐? (가짜가 아니고)" 라고 질문하는 것

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.fc1 = nn.Linear(784, 548)
        self.fc2 = nn.Linear(548, 252)
        self.fc3 = nn.Linear(252, 1)
        
        self.bc1 = nn.BatchNorm1d(548)
        self.bc2 = nn.BatchNorm1d(252)
                
    def forward(self, x):
        x = x.view((-1, 784))
        h = self.fc1(x)
        h = self.bc1(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.5, training=self.training)
        
        h = self.fc2(h)
        h = self.bc2(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.2, training=self.training)
        
        h = self.fc3(h)
        out = F.sigmoid(h)
        return out

D = Discriminator()
print(D.cuda()) # CUDA!
d_optimizer = optim.Adam(D.parameters(), lr=0.001)
# Out:
# Discriminator (
#   (fc1): Linear (784 -> 548)
#   (fc2): Linear (548 -> 252)
#   (fc3): Linear (252 -> 1)
#   (bc1): BatchNorm1d(548, eps=1e-05, momentum=0.1, affine=True)
#   (bc2): BatchNorm1d(252, eps=1e-05, momentum=0.1, affine=True)
# )

# %% [markdown]
# ### Generator

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        
        self.fc1 = nn.Linear(100, 196)
        self.fc2 = nn.Linear(196, 289)
        self.fc3 = nn.Linear(289, 361)
        self.fc4 = nn.Linear(361, 529)
        self.fc5 = nn.Linear(529, 784)
        
        self.bc1 = nn.BatchNorm1d(196)
        self.bc2 = nn.BatchNorm1d(289)
        self.bc3 = nn.BatchNorm1d(361)
        self.bc4 = nn.BatchNorm1d(529)
    
    def forward(self, x):
        h = self.fc1(x)
        h = self.bc1(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.5, training=self.training)
        
        h = self.fc2(h)
        h = self.bc2(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.3, training=self.training)
        
        h = self.fc3(h)
        h = self.bc3(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.2, training=self.training)
        
        h = self.fc4(h)
        h = self.bc4(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.2, training=self.training)
        
        h = self.fc5(h)
        out = F.sigmoid(h)
        return out

G = Generator()
print(G.cuda())
g_optimizer = optim.Adam(G.parameters(), lr=0.001)
# Out:
# Generator (
#   (fc1): Linear (100 -> 196)
#   (fc2): Linear (196 -> 289)
#   (fc3): Linear (289 -> 361)
#   (fc4): Linear (361 -> 529)
#   (fc5): Linear (529 -> 784)
#   (bc1): BatchNorm1d(196, eps=1e-05, momentum=0.1, affine=True)
#   (bc2): BatchNorm1d(289, eps=1e-05, momentum=0.1, affine=True)
#   (bc3): BatchNorm1d(361, eps=1e-05, momentum=0.1, affine=True)
#   (bc4): BatchNorm1d(529, eps=1e-05, momentum=0.1, affine=True)
# )

# %% [markdown]
# ## Train
#
# * $ 1 $ : real images
# * $ 0 $ : fake images

# %%
N_EPOCH = 60

real_y = Variable(torch.ones((BATCH_SIZE, 1)).cuda())
fake_y = Variable(torch.zeros((BATCH_SIZE, 1)).cuda())
loss_f = nn.BCELoss()

d_real_losses = list()
d_fake_losses = list()
g_losses = list()

# %%
# Train Discriminator with Generator not being trained
# 먼저 Discriminator를 학습시킵니다.
# 이때 real image와 fake이미지 두개의 데이터를 사용하여 학습합니다. 
# Discriminator를 학습시킬때는 Generator는 학습시키면 안됩니다.

for epoch in range(N_EPOCH):
    _d_real_losses = list()
    _d_fake_losses = list()
    _g_losses = list()
    
    
    for step, (real_images, _) in enumerate(train_loader):
        real_images = Variable(real_images.cuda())

        # Init D
        d_optimizer.zero_grad()

        ###############################################
        # Train D with real images
        ###############################################
        y_real_pred = D(real_images)
        d_real_loss = loss_f(y_real_pred, real_y)
        d_real_loss.backward()
        d_optimizer.step()
        
        # Visualization
        _d_real_losses.append(d_real_loss.data[0])

        ###############################################
        # Train D with fake images but do not train G
        ###############################################
        fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
        fake_images = G(fake_distributions).detach()
        y_pred = D(fake_images)
        d_fake_loss = loss_f(y_pred, fake_y)
        d_fake_loss.backward()
        d_optimizer.step()
        
        # Visualization
        _d_fake_losses.append(d_fake_loss.data[0])

        ###############################################
        # Train G with fake images but do not train G
        ###############################################
        g_optimizer.zero_grad()
        
        fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
        fake_images = G(fake_distributions)
        y_pred = D(fake_images)
        g_loss = loss_f(y_pred, real_y)
        g_loss.backward()
        g_optimizer.step()
        
        # Visualization
        _g_losses.append(g_loss.data.cpu().numpy()[0])
        
        if step % 100 == 0:
            _d_real_losses = np.array(_d_real_losses)
            _d_fake_losses = np.array(_d_fake_losses)
            _g_losses = np.array(_g_losses)
            
            d_real_losses.append(_d_real_losses.mean())
            d_fake_losses.append(_d_fake_losses.mean())
            g_losses.append(_g_losses.mean())
            
            _d_real_losses = list()
            _d_fake_losses = list()
            _g_losses = list()
            
            print(f'\rEpoch:[{epoch}] Step:[{step}] -',
                  '[D_real_loss]: {:.4}'.format(d_real_loss.data[0]),
                  '[D_fake_loss]: {:.4}'.format(d_fake_loss.data[0]), 
                  '[G_loss]:{:.4}'.format(g_loss.data[0]), end='') 
    print()
# Out:
# Epoch:[0] Step:[1800] - [D_real_loss]: 0.2536 [D_fake_loss]: 0.2461 [G_loss]:2.0293
# Epoch:[1] Step:[1800] - [D_real_loss]: 0.226 [D_fake_loss]: 0.7531 [G_loss]:1.08858
# Epoch:[2] Step:[1800] - [D_real_loss]: 0.1276 [D_fake_loss]: 0.4466 [G_loss]:2.23543
# Epoch:[3] Step:[1800] - [D_real_loss]: 0.2926 [D_fake_loss]: 0.3945 [G_loss]:2.53959
# Epoch:[4] Step:[1800] - [D_real_loss]: 0.3281 [D_fake_loss]: 1.771 [G_loss]:1.607252
# Epoch:[5] Step:[1800] - [D_real_loss]: 0.1172 [D_fake_loss]: 0.2764 [G_loss]:2.9083
# Epoch:[6] Step:[1800] - [D_real_loss]: 0.03619 [D_fake_loss]: 1.037 [G_loss]:1.0416
# Epoch:[7] Step:[1800] - [D_real_loss]: 0.06104 [D_fake_loss]: 0.4846 [G_loss]:0.4477
# Epoch:[8] Step:[1800] - [D_real_loss]: 0.05267 [D_fake_loss]: 0.4666 [G_loss]:1.857
# Epoch:[9] Step:[1800] - [D_real_loss]: 0.06268 [D_fake_loss]: 0.278 [G_loss]:2.34696
# Epoch:[38] Step:[1800] - [D_real_loss]: 0.3164 [D_fake_loss]: 0.1084 [G_loss]:2.40897
# Epoch:[39] Step:[1800] - [D_real_loss]: 0.1276 [D_fake_loss]: 0.6374 [G_loss]:0.78921
# Epoch:[40] Step:[1800] - [D_real_loss]: 0.2742 [D_fake_loss]: 0.497 [G_loss]:1.222772
# Epoch:[41] Step:[1800] - [D_real_loss]: 0.04199 [D_fake_loss]: 0.7146 [G_loss]:0.4635
# Epoch:[42] Step:[1800] - [D_real_loss]: 0.5511 [D_fake_loss]: 0.6157 [G_loss]:1.53787
# Epoch:[43] Step:[1800] - [D_real_loss]: 0.08812 [D_fake_loss]: 0.5581 [G_loss]:0.6777
# Epoch:[44] Step:[1800] - [D_real_loss]: 0.3076 [D_fake_loss]: 1.023 [G_loss]:3.79935
# Epoch:[45] Step:[1800] - [D_real_loss]: 0.01547 [D_fake_loss]: 0.3631 [G_loss]:2.77835
# Epoch:[46] Step:[1800] - [D_real_loss]: 0.06064 [D_fake_loss]: 0.2287 [G_loss]:2.767
# Epoch:[47] Step:[1800] - [D_real_loss]: 0.1042 [D_fake_loss]: 0.3976 [G_loss]:2.38694
# Epoch:[48] Step:[1800] - [D_real_loss]: 0.9432 [D_fake_loss]: 1.48 [G_loss]:1.6656289
# Epoch:[49] Step:[1800] - [D_real_loss]: 0.00789 [D_fake_loss]: 0.2945 [G_loss]:0.4938
# Epoch:[50] Step:[1800] - [D_real_loss]: 0.186 [D_fake_loss]: 0.8518 [G_loss]:0.3623132
# Epoch:[51] Step:[1800] - [D_real_loss]: 0.3224 [D_fake_loss]: 0.7529 [G_loss]:0.4263
# Epoch:[52] Step:[1800] - [D_real_loss]: 0.07015 [D_fake_loss]: 0.1303 [G_loss]:1.635
# Epoch:[53] Step:[1800] - [D_real_loss]: 0.09783 [D_fake_loss]: 1.281 [G_loss]:1.2839
# Epoch:[54] Step:[1800] - [D_real_loss]: 0.3921 [D_fake_loss]: 0.6257 [G_loss]:2.011932
# Epoch:[55] Step:[1800] - [D_real_loss]: 0.2105 [D_fake_loss]: 0.488 [G_loss]:1.1913
# Epoch:[56] Step:[1800] - [D_real_loss]: 0.04676 [D_fake_loss]: 0.3343 [G_loss]:0.5849
# Epoch:[57] Step:[1800] - [D_real_loss]: 0.1644 [D_fake_loss]: 1.518 [G_loss]:3.436745
# Epoch:[58] Step:[1800] - [D_real_loss]: 0.03027 [D_fake_loss]: 0.3108 [G_loss]:2.4182
# Epoch:[59] Step:[1800] - [D_real_loss]: 0.1159 [D_fake_loss]: 0.434 [G_loss]:1.537154

# %% [markdown]
# ## Loss Visualization

# %%
plot(d_real_losses, label='D(x) Loss')
plot(d_fake_losses, label='D(G(z)) Loss')
plot(g_losses, label='G(z) loss')

grid()
legend()
figsize(16, 6)

# %%
fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
images = G(fake_distributions).view((-1, 28, 28)).data.cpu().numpy()

images[0]
imshow(images[0], cmap=cm.gray_r)

fig, subplots = pylab.subplots(4, 5) # subplots(y축, x축 갯수)

idx = 10
for _subs in subplots:
    for subplot in _subs:
        d = images[idx]
        subplot.get_xaxis().set_visible(False)
        subplot.get_yaxis().set_visible(False)
        subplot.imshow(d, cmap=cm.gray_r)
        idx += 1
