# %%
# %pylab inline
import numpy as np
import torch

from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.autograd import Variable
from torch.utils.data import dataloader

from torchvision import transforms
from torchvision.datasets import MNIST

from graphviz import Digraph
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['test']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ## Configuration

# %%
BATCH_SIZE = 32

# %% [markdown]
# ## Data (MNIST)

# %%
train = MNIST('./data', train=True, download=True, transform=transforms.Compose([
    transforms.ToTensor(), # ToTensor does min-max normalization. 
]), )

test = MNIST('./data', train=False, download=True, transform=transforms.Compose([
    transforms.ToTensor(), # ToTensor does min-max normalization. 
    
]), )

# Create DataLoader
dataloader_args = dict(shuffle=True, batch_size=BATCH_SIZE ,num_workers=1, pin_memory=True)
train_loader = dataloader.DataLoader(train, **dataloader_args)
test_loader = dataloader.DataLoader(test, **dataloader_args)

# %% [markdown]
# ## Model Discriminator
#
# ### Discriminator
#
# * $ x_i \sim P_{\rm data} $ (즉 true data distribution) 에서 왔다면 1
# * $ x_i = G(z) $ 이때 $ z \sim p_{\rm generator} $ (generators' distribution)에서 왔다면 0
#
# 즉 Discriminator는 "이 사진이 진짜냐? (가짜가 아니고)" 라고 질문하는 것

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.fc1 = nn.Linear(784, 548)
        self.fc2 = nn.Linear(548, 252)
        self.fc3 = nn.Linear(252, 1)
        
        self.bc1 = nn.BatchNorm1d(548)
        self.bc2 = nn.BatchNorm1d(252)
                
    def forward(self, x):
        x = x.view((-1, 784))
        h = self.fc1(x)
        h = self.bc1(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.5, training=self.training)
        
        h = self.fc2(h)
        h = self.bc2(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.2, training=self.training)
        
        h = self.fc3(h)
        out = F.sigmoid(h)
        return out

D = Discriminator()
print(D.cuda()) # CUDA!
d_optimizer = optim.Adam(D.parameters(), lr=0.001)
# Out:
# Discriminator (
#   (fc1): Linear (784 -> 548)
#   (fc2): Linear (548 -> 252)
#   (fc3): Linear (252 -> 1)
#   (bc1): BatchNorm1d(548, eps=1e-05, momentum=0.1, affine=True)
#   (bc2): BatchNorm1d(252, eps=1e-05, momentum=0.1, affine=True)
# )

# %% [markdown]
# ### Generator

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        
        self.fc1 = nn.Linear(100, 196)
        self.fc2 = nn.Linear(196, 289)
        self.fc3 = nn.Linear(289, 361)
        self.fc4 = nn.Linear(361, 529)
        self.fc5 = nn.Linear(529, 784)
        
        self.bc1 = nn.BatchNorm1d(196)
        self.bc2 = nn.BatchNorm1d(289)
        self.bc3 = nn.BatchNorm1d(361)
        self.bc4 = nn.BatchNorm1d(529)
    
    def forward(self, x):
        h = self.fc1(x)
        h = self.bc1(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.5, training=self.training)
        
        h = self.fc2(h)
        h = self.bc2(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.3, training=self.training)
        
        h = self.fc3(h)
        h = self.bc3(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.2, training=self.training)
        
        h = self.fc4(h)
        h = self.bc4(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.2, training=self.training)
        
        h = self.fc5(h)
        out = F.sigmoid(h)
        return out

G = Generator()
print(G.cuda())
g_optimizer = optim.Adam(G.parameters(), lr=0.001)
# Out:
# Generator (
#   (fc1): Linear (100 -> 196)
#   (fc2): Linear (196 -> 289)
#   (fc3): Linear (289 -> 361)
#   (fc4): Linear (361 -> 529)
#   (fc5): Linear (529 -> 784)
#   (bc1): BatchNorm1d(196, eps=1e-05, momentum=0.1, affine=True)
#   (bc2): BatchNorm1d(289, eps=1e-05, momentum=0.1, affine=True)
#   (bc3): BatchNorm1d(361, eps=1e-05, momentum=0.1, affine=True)
#   (bc4): BatchNorm1d(529, eps=1e-05, momentum=0.1, affine=True)
# )

# %% [markdown]
# ## Visualization

# %%
def make_dot(var):
    node_attr = dict(style='filled',
                     shape='box',
                     align='left',
                     fontsize='12',
                     ranksep='0.1',
                     height='0.2')
    dot = Digraph(node_attr=node_attr, graph_attr=dict(size="12,12"))
    seen = set()

    def add_nodes(var):
        if var not in seen:
            if isinstance(var, Variable):
                value = '('+(', ').join(['%d'% v for v in var.size()])+')'
                dot.node(str(id(var)), str(value), fillcolor='lightblue')
            else:
                dot.node(str(id(var)), str(type(var).__name__))
            seen.add(var)
            if hasattr(var, 'previous_functions'):
                for u in var.previous_functions:
                    dot.edge(str(id(u[0])), str(id(var)))
                    add_nodes(u[0])
    add_nodes(var.creator)
    return dot

# %%
real_image = train[0][0].cuda()
real_image = Variable(real_image)
make_dot(D(real_image))

# %%
fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
images = G(fake_distributions).view((-1, 28, 28))
make_dot(images)

# %% [markdown]
# ## Train
#
# * $ 1 $ : real images
# * $ 0 $ : fake images

# %%
N_EPOCH = 100

real_y = Variable(torch.ones((BATCH_SIZE, 1)).cuda())
fake_y = Variable(torch.zeros((BATCH_SIZE, 1)).cuda())
loss_f = nn.BCELoss()

d_real_losses = list()
d_fake_losses = list()
g_losses = list()

# %%
# Train Discriminator with Generator not being trained
# 먼저 Discriminator를 학습시킵니다.
# 이때 real image와 fake이미지 두개의 데이터를 사용하여 학습합니다. 
# Discriminator를 학습시킬때는 Generator는 학습시키면 안됩니다.

for epoch in range(N_EPOCH):
    _d_real_losses = list()
    _d_fake_losses = list()
    _g_losses = list()
    
    
    for step, (real_images, _) in enumerate(train_loader):
        real_images = Variable(real_images.cuda())

        # Init D
        d_optimizer.zero_grad()

        ###############################################
        # Train D with real images
        ###############################################
        y_real_pred = D(real_images)
        d_real_loss = loss_f(y_real_pred, real_y)
        d_real_loss.backward()
        d_optimizer.step()
        
        # Visualization
        _d_real_losses.append(d_real_loss.data[0])

        ###############################################
        # Train D with fake images but do not train G
        ###############################################
        fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
        fake_images = G(fake_distributions).detach()
        y_pred = D(fake_images)
        d_fake_loss = loss_f(y_pred, fake_y)
        d_fake_loss.backward()
        d_optimizer.step()
        
        # Visualization
        _d_fake_losses.append(d_fake_loss.data[0])

        ###############################################
        # Train G with fake images but do not train G
        ###############################################
        g_optimizer.zero_grad()
        
        fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
        fake_images = G(fake_distributions)
        y_pred = D(fake_images)
        g_loss = loss_f(y_pred, real_y)
        g_loss.backward()
        g_optimizer.step()
        
        # Visualization
        _g_losses.append(g_loss.data.cpu().numpy()[0])
        
        if step % 200 == 0:
            _d_real_losses = np.array(_d_real_losses)
            _d_fake_losses = np.array(_d_fake_losses)
            _g_losses = np.array(_g_losses)
            
            d_real_losses.append(_d_real_losses.mean())
            d_fake_losses.append(_d_fake_losses.mean())
            g_losses.append(_g_losses.mean())
            
            _d_real_losses = list()
            _d_fake_losses = list()
            _g_losses = list()
            
            print(f'\rEpoch:[{epoch}] Step:[{step}] -',
                  '[D_real_loss]: {:.4}'.format(d_real_loss.data[0]),
                  '[D_fake_loss]: {:.4}'.format(d_fake_loss.data[0]), 
                  '[G_loss]:{:.4}'.format(g_loss.data[0]), end='') 
    print()
# Out:
# Epoch:[0] Step:[1800] - [D_real_loss]: 0.04605 [D_fake_loss]: 0.5393 [G_loss]:2.4467
# Epoch:[1] Step:[1800] - [D_real_loss]: 0.3806 [D_fake_loss]: 1.408 [G_loss]:3.07887
# Epoch:[2] Step:[1800] - [D_real_loss]: 0.08285 [D_fake_loss]: 0.2951 [G_loss]:3.4116
# Epoch:[3] Step:[1800] - [D_real_loss]: 0.06229 [D_fake_loss]: 0.09555 [G_loss]:1.614
# Epoch:[4] Step:[1800] - [D_real_loss]: 0.008691 [D_fake_loss]: 0.9724 [G_loss]:1.348
# Epoch:[5] Step:[1800] - [D_real_loss]: 0.01324 [D_fake_loss]: 0.2641 [G_loss]:2.6956
# Epoch:[6] Step:[1800] - [D_real_loss]: 0.2643 [D_fake_loss]: 0.2674 [G_loss]:2.07247
# Epoch:[7] Step:[1800] - [D_real_loss]: 0.0411 [D_fake_loss]: 0.1873 [G_loss]:2.7012
# Epoch:[8] Step:[1800] - [D_real_loss]: 0.0468 [D_fake_loss]: 0.4728 [G_loss]:0.43943
# Epoch:[9] Step:[1800] - [D_real_loss]: 0.01478 [D_fake_loss]: 0.7266 [G_loss]:2.7876
# Epoch:[10] Step:[1800] - [D_real_loss]: 1.895 [D_fake_loss]: 0.8621 [G_loss]:1.5222
# Epoch:[11] Step:[1800] - [D_real_loss]: 0.2718 [D_fake_loss]: 1.069 [G_loss]:0.86835
# Epoch:[12] Step:[1800] - [D_real_loss]: 0.6944 [D_fake_loss]: 0.04203 [G_loss]:1.786
# Epoch:[13] Step:[1800] - [D_real_loss]: 0.6834 [D_fake_loss]: 1.135 [G_loss]:2.315134
# Epoch:[14] Step:[1800] - [D_real_loss]: 0.01552 [D_fake_loss]: 0.5331 [G_loss]:2.3776
# Epoch:[15] Step:[1800] - [D_real_loss]: 0.02487 [D_fake_loss]: 0.8934 [G_loss]:1.135
# Epoch:[16] Step:[1800] - [D_real_loss]: 0.3388 [D_fake_loss]: 0.211 [G_loss]:1.75136
# Epoch:[17] Step:[1800] - [D_real_loss]: 0.389 [D_fake_loss]: 0.4708 [G_loss]:1.63139
# Epoch:[18] Step:[1800] - [D_real_loss]: 0.2152 [D_fake_loss]: 2.039 [G_loss]:3.27405
# Epoch:[19] Step:[1800] - [D_real_loss]: 0.584 [D_fake_loss]: 0.53 [G_loss]:1.62:2.834
# Epoch:[20] Step:[1800] - [D_real_loss]: 2.887 [D_fake_loss]: 1.915 [G_loss]:1.86965
# Epoch:[21] Step:[1800] - [D_real_loss]: 0.06142 [D_fake_loss]: 0.1757 [G_loss]:1.293
# Epoch:[22] Step:[1800] - [D_real_loss]: 0.01351 [D_fake_loss]: 1.07 [G_loss]:0.78742
# Epoch:[23] Step:[1800] - [D_real_loss]: 0.3625 [D_fake_loss]: 0.4695 [G_loss]:1.4762
# Epoch:[24] Step:[1800] - [D_real_loss]: 0.2731 [D_fake_loss]: 0.3431 [G_loss]:1.54676
# Epoch:[25] Step:[1800] - [D_real_loss]: 0.9785 [D_fake_loss]: 1.361 [G_loss]:1.694769
# Epoch:[26] Step:[1800] - [D_real_loss]: 0.1562 [D_fake_loss]: 0.35 [G_loss]:0.354821
# Epoch:[27] Step:[1800] - [D_real_loss]: 0.004032 [D_fake_loss]: 0.1457 [G_loss]:1.263
# Epoch:[28] Step:[1800] - [D_real_loss]: 0.7745 [D_fake_loss]: 1.241 [G_loss]:1.774512
# Epoch:[29] Step:[1800] - [D_real_loss]: 0.03148 [D_fake_loss]: 0.185 [G_loss]:3.97215
# Epoch:[30] Step:[1800] - [D_real_loss]: 0.0151 [D_fake_loss]: 1.067 [G_loss]:0.74824
# Epoch:[31] Step:[1800] - [D_real_loss]: 0.703 [D_fake_loss]: 0.281 [G_loss]:1.741632
# Epoch:[32] Step:[1800] - [D_real_loss]: 1.328 [D_fake_loss]: 0.2493 [G_loss]:0.785459
# Epoch:[33] Step:[1800] - [D_real_loss]: 0.01741 [D_fake_loss]: 0.126 [G_loss]:0.8794
# Epoch:[34] Step:[1800] - [D_real_loss]: 0.06335 [D_fake_loss]: 0.4295 [G_loss]:1.455
# Epoch:[35] Step:[1800] - [D_real_loss]: 0.02387 [D_fake_loss]: 0.4461 [G_loss]:1.3795
# Epoch:[36] Step:[1800] - [D_real_loss]: 0.03329 [D_fake_loss]: 0.6157 [G_loss]:2.66727
# Epoch:[37] Step:[1800] - [D_real_loss]: 1.071 [D_fake_loss]: 0.37 [G_loss]:0.1446259
# Epoch:[38] Step:[1800] - [D_real_loss]: 0.07406 [D_fake_loss]: 0.4466 [G_loss]:1.436
# Epoch:[39] Step:[1800] - [D_real_loss]: 0.007586 [D_fake_loss]: 0.08466 [G_loss]:1.938
# Epoch:[40] Step:[1800] - [D_real_loss]: 0.2944 [D_fake_loss]: 0.8039 [G_loss]:2.6115
# Epoch:[41] Step:[1800] - [D_real_loss]: 0.008727 [D_fake_loss]: 0.03401 [G_loss]:1.449
# Epoch:[42] Step:[1800] - [D_real_loss]: 0.159 [D_fake_loss]: 3.864 [G_loss]:2.2562988
# Epoch:[43] Step:[1800] - [D_real_loss]: 0.04144 [D_fake_loss]: 0.8691 [G_loss]:3.5478
# Epoch:[44] Step:[1800] - [D_real_loss]: 0.3512 [D_fake_loss]: 0.1088 [G_loss]:3.66297
# Epoch:[45] Step:[1800] - [D_real_loss]: 0.05019 [D_fake_loss]: 0.156 [G_loss]:1.42562
# Epoch:[46] Step:[1800] - [D_real_loss]: 0.4752 [D_fake_loss]: 0.5767 [G_loss]:0.3779
# Epoch:[47] Step:[1800] - [D_real_loss]: 0.05184 [D_fake_loss]: 0.1236 [G_loss]:1.7855
# Epoch:[48] Step:[1800] - [D_real_loss]: 0.02872 [D_fake_loss]: 1.795 [G_loss]:1.4163
# Epoch:[49] Step:[1800] - [D_real_loss]: 0.1633 [D_fake_loss]: 0.5375 [G_loss]:1.8176
# Epoch:[50] Step:[1800] - [D_real_loss]: 0.06358 [D_fake_loss]: 1.291 [G_loss]:2.59717
# Epoch:[51] Step:[1800] - [D_real_loss]: 0.3035 [D_fake_loss]: 0.7659 [G_loss]:1.2992
# Epoch:[52] Step:[1800] - [D_real_loss]: 0.1486 [D_fake_loss]: 0.8903 [G_loss]:1.4068
# Epoch:[53] Step:[1800] - [D_real_loss]: 0.03148 [D_fake_loss]: 0.1989 [G_loss]:1.436
# Epoch:[54] Step:[1800] - [D_real_loss]: 0.6848 [D_fake_loss]: 0.3152 [G_loss]:1.8888
# Epoch:[55] Step:[1800] - [D_real_loss]: 0.06918 [D_fake_loss]: 0.3447 [G_loss]:2.066
# Epoch:[56] Step:[1800] - [D_real_loss]: 0.6227 [D_fake_loss]: 0.1683 [G_loss]:0.81654
# Epoch:[57] Step:[1800] - [D_real_loss]: 0.5394 [D_fake_loss]: 0.3504 [G_loss]:2.11554
# Epoch:[58] Step:[1800] - [D_real_loss]: 0.039 [D_fake_loss]: 0.3102 [G_loss]:0.9184222
# Epoch:[59] Step:[1800] - [D_real_loss]: 0.07475 [D_fake_loss]: 0.579 [G_loss]:2.5211
# Epoch:[60] Step:[1800] - [D_real_loss]: 0.4318 [D_fake_loss]: 0.213 [G_loss]:2.916834
# Epoch:[61] Step:[1800] - [D_real_loss]: 0.164 [D_fake_loss]: 0.9732 [G_loss]:1.96521
# Epoch:[62] Step:[1800] - [D_real_loss]: 0.02445 [D_fake_loss]: 0.3451 [G_loss]:2.04962
# Epoch:[63] Step:[1800] - [D_real_loss]: 0.02814 [D_fake_loss]: 0.5474 [G_loss]:1.562
# Epoch:[64] Step:[1800] - [D_real_loss]: 0.659 [D_fake_loss]: 0.1834 [G_loss]:1.257795
# Epoch:[65] Step:[1800] - [D_real_loss]: 1.327 [D_fake_loss]: 0.2057 [G_loss]:3.799745
# Epoch:[66] Step:[1800] - [D_real_loss]: 0.21 [D_fake_loss]: 0.2055 [G_loss]:2.275791
# Epoch:[67] Step:[1800] - [D_real_loss]: 0.2223 [D_fake_loss]: 0.1573 [G_loss]:2.477
# Epoch:[68] Step:[1800] - [D_real_loss]: 0.02921 [D_fake_loss]: 1.432 [G_loss]:2.8963
# Epoch:[69] Step:[1800] - [D_real_loss]: 0.01915 [D_fake_loss]: 1.554 [G_loss]:1.6858
# Epoch:[70] Step:[1800] - [D_real_loss]: 0.05378 [D_fake_loss]: 0.8369 [G_loss]:1.526
# Epoch:[71] Step:[1800] - [D_real_loss]: 0.0136 [D_fake_loss]: 0.2864 [G_loss]:2.43685
# Epoch:[72] Step:[1800] - [D_real_loss]: 0.0817 [D_fake_loss]: 0.7056 [G_loss]:1.3487
# Epoch:[73] Step:[1800] - [D_real_loss]: 0.4429 [D_fake_loss]: 1.298 [G_loss]:3.451094
# Epoch:[74] Step:[1800] - [D_real_loss]: 0.05369 [D_fake_loss]: 0.2484 [G_loss]:1.159
# Epoch:[75] Step:[1800] - [D_real_loss]: 0.06939 [D_fake_loss]: 0.4268 [G_loss]:1.5872
# Epoch:[76] Step:[1800] - [D_real_loss]: 0.01124 [D_fake_loss]: 0.2713 [G_loss]:1.828
# Epoch:[77] Step:[1800] - [D_real_loss]: 0.00477 [D_fake_loss]: 0.9884 [G_loss]:0.8184
# Epoch:[78] Step:[1800] - [D_real_loss]: 0.008217 [D_fake_loss]: 0.7964 [G_loss]:1.206
# Epoch:[79] Step:[1800] - [D_real_loss]: 0.09921 [D_fake_loss]: 0.1808 [G_loss]:1.9786
# Epoch:[80] Step:[1800] - [D_real_loss]: 0.04688 [D_fake_loss]: 0.2373 [G_loss]:4.201
# Epoch:[81] Step:[1800] - [D_real_loss]: 0.06764 [D_fake_loss]: 0.8715 [G_loss]:0.9232
# Epoch:[82] Step:[1800] - [D_real_loss]: 0.04416 [D_fake_loss]: 0.2452 [G_loss]:2.1682
# Epoch:[83] Step:[1800] - [D_real_loss]: 0.01234 [D_fake_loss]: 0.1829 [G_loss]:1.401
# Epoch:[84] Step:[1800] - [D_real_loss]: 0.004524 [D_fake_loss]: 0.1125 [G_loss]:2.984
# Epoch:[85] Step:[1800] - [D_real_loss]: 0.1872 [D_fake_loss]: 0.3259 [G_loss]:0.9678
# Epoch:[86] Step:[1800] - [D_real_loss]: 0.1992 [D_fake_loss]: 0.02272 [G_loss]:2.3668
# Epoch:[87] Step:[1800] - [D_real_loss]: 0.3635 [D_fake_loss]: 0.1712 [G_loss]:3.41956
# Epoch:[88] Step:[1800] - [D_real_loss]: 0.007464 [D_fake_loss]: 0.05073 [G_loss]:1.357
# Epoch:[89] Step:[1800] - [D_real_loss]: 1.084 [D_fake_loss]: 0.118 [G_loss]:3.4724932
# Epoch:[90] Step:[1800] - [D_real_loss]: 0.03018 [D_fake_loss]: 0.2388 [G_loss]:2.7167
# Epoch:[91] Step:[1800] - [D_real_loss]: 0.005446 [D_fake_loss]: 0.1865 [G_loss]:2.777
# Epoch:[92] Step:[1800] - [D_real_loss]: 0.1114 [D_fake_loss]: 0.1196 [G_loss]:1.99381
# Epoch:[93] Step:[1800] - [D_real_loss]: 0.8068 [D_fake_loss]: 0.341 [G_loss]:2.83352
# Epoch:[94] Step:[1800] - [D_real_loss]: 0.01648 [D_fake_loss]: 0.4754 [G_loss]:0.3547
# Epoch:[95] Step:[1800] - [D_real_loss]: 0.5418 [D_fake_loss]: 0.4633 [G_loss]:1.74673
# Epoch:[96] Step:[1800] - [D_real_loss]: 0.1368 [D_fake_loss]: 0.1497 [G_loss]:3.1671
# Epoch:[97] Step:[1800] - [D_real_loss]: 0.3741 [D_fake_loss]: 0.3273 [G_loss]:1.17582
# Epoch:[98] Step:[1800] - [D_real_loss]: 0.06041 [D_fake_loss]: 0.137 [G_loss]:0.21836
# Epoch:[99] Step:[1800] - [D_real_loss]: 0.01912 [D_fake_loss]: 0.3144 [G_loss]:3.9537

# %% [markdown]
# ## Loss Visualization

# %%
plot(d_real_losses, label='D(x) Loss')
plot(d_fake_losses, label='D(G(z)) Loss')
plot(g_losses, label='G(z) loss')

grid()
legend()
figsize(16, 6)

# %%
fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
images = G(fake_distributions).view((-1, 28, 28)).data.cpu().numpy()

images[0]
imshow(images[0], cmap=cm.gray_r)

fig, subplots = pylab.subplots(4, 7) # subplots(y축, x축 갯수)

idx = 0
for _subs in subplots:
    for subplot in _subs:
        d = images[idx]
        subplot.get_xaxis().set_visible(False)
        subplot.get_yaxis().set_visible(False)
        subplot.imshow(d, cmap=cm.gray_r)
        idx += 1
