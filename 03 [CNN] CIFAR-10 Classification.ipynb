# %%
# %pylab inline

import torch
import torchvision

from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import CIFAR10
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Configuration

# %%
BATCH_SIZE = 50

# %% [markdown]
# # CIFAR-10 Data

# %%
cifar_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])
trainset = CIFAR10('./data', train=True, download=True, transform=cifar_transform)
testset = CIFAR10('./data', train=False, download=True, transform=cifar_transform)

train_loader = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
test_loader = DataLoader(testset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)

CLASSES = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print('Train Shape:', trainset.train_data.shape)
print('Test Shape:', testset.test_data.shape)

print('Train Loader Weight Size:', iter(train_loader).next()[0].size())
print('Train Loader Bias   Size:', iter(train_loader).next()[1].size())

# iter(train_loader).next()[0].numpy().shape()
# Out:
# Train Shape: (50000, 32, 32, 3)
# Test Shape: (10000, 32, 32, 3)
# Train Loader Weight Size: torch.Size([50, 3, 32, 32])
# Train Loader Bias   Size: torch.Size([50])

# %%
_to_pil = transforms.ToPILImage()

figsize(10, 7)
fig, subplots = pylab.subplots(5, 7) # subplots(y축, x축 갯수)

idx = 10
for _subs in subplots:
    for subplot in _subs:
        images, labels = train_iter.next()
        subplot.get_xaxis().set_visible(False)
        subplot.get_yaxis().set_visible(False)
        subplot.imshow(_to_pil(trainset.train_data[idx]))
        idx += 1

# %%
transforms.Scale()
iter(train_loader).next()[0][0].numpy()
# Out:
# array([[[[ 187.        ,  185.        ,  181.        , ...,  183.        ,
#            185.        ,  185.        ],
#          [ 223.        ,  219.        ,  217.        , ...,  227.        ,
#            225.        ,  221.        ],
#          [ 207.        ,  209.        ,  203.        , ...,  213.        ,
#            211.        ,  211.        ],
#          ...,
#          [ 131.        ,  125.00000763,   37.00001144, ...,  -34.99999619,
#              5.00001478,  113.00000763],
#          [ 117.00000763,  115.00000763,   89.00000763, ...,    3.00001502,
#              5.00001478,  113.00000763],
#          [ 135.        ,  131.        ,  103.00000763, ...,  -78.99999237,
#            -28.99999809,   81.00000763]],
#
#         [[ 187.        ,  185.        ,  181.        , ...,  185.        ,
#            187.        ,  187.        ],
#          [ 229.        ,  225.        ,  221.        , ...,  233.        ,
#            231.        ,  227.        ],
#          [ 215.        ,  215.        ,  209.        , ...,  223.        ,
#            219.        ,  221.        ],
#          ...,
#          [ 167.        ,  155.        ,   61.00001144, ...,  -12.99999905,
#             27.00001335,  135.        ],
#          [ 149.        ,  141.        ,  109.00000763, ...,   31.00001335,
#             33.00001144,  139.        ],
#          [ 163.        ,  155.        ,  119.00000763, ...,  -50.99999619,
#              1.00001514,  107.00000763]],
#
#         [[ 207.        ,  205.        ,  201.        , ...,  189.        ,
#            191.        ,  191.        ],
#          [ 245.        ,  243.        ,  239.        , ...,  239.        ,
#            237.        ,  233.        ],
#          [ 231.        ,  233.        ,  227.        , ...,  231.        ,
#            227.        ,  229.        ],
#          ...,
#          [ 195.        ,  177.        ,   79.00000763, ...,    7.00001478,
#             47.00001144,  155.        ],
#          [ 179.        ,  165.        ,  129.        , ...,   51.00001144,
#             55.00001144,  163.        ],
#          [ 193.        ,  179.        ,  143.        , ...,  -24.99999809,
#             25.00001335,  133.        ]]],
#
#
#        [[[  85.00000763,   87.00000763,   63.00001144, ...,   21.00001335,
#             -8.99999905,  -44.99999619],
#          [  65.00000763,   21.00001335,   15.00001431, ...,   35.00001144,
#            -30.99999809,  -22.99999809],
#          [  53.00001144,  -46.99999619,   -4.99999952, ...,   25.00001335,
#             15.00001431,  -18.99999809],
#          ...,
#          [-100.99999237,  -90.99999237,  -88.99999237, ...,  -76.99999237,
#            -78.99999237,  -84.99999237],
#          [ -96.99999237,  -90.99999237,  -84.99999237, ...,  -74.99999237,
#            -80.99999237,  -76.99999237],
#          [ -90.99999237,  -82.99999237,  -84.99999237, ...,  -80.99999237,
#            -78.99999237,  -66.99999237]],
#
#         [[  87.00000763,   89.00000763,   65.00000763, ...,   29.00001335,
#             -0.99999994,  -38.99999619],
#          [  67.00000763,   23.00001335,   17.00001335, ...,   43.00001144,
#            -22.99999809,  -14.99999905],
#          [  55.00001144,  -44.99999619,   -2.99999976, ...,   33.00001144,
#             23.00001335,  -12.99999905],
#          ...,
#          [ -62.99999619,  -62.99999619,  -64.99999237, ...,  -44.99999619,
#            -46.99999619,  -52.99999619],
#          [ -66.99999237,  -60.99999619,  -56.99999619, ...,  -44.99999619,
#            -50.99999619,  -46.99999619],
#          [ -62.99999619,  -54.99999619,  -56.99999619, ...,  -50.99999619,
#            -48.99999619,  -36.99999619]],
#
#         [[  75.00000763,   77.00000763,   53.00001144, ...,  -22.99999809,
#            -48.99999619,  -78.99999237],
#          [  55.00001144,   11.00001431,    5.00001478, ...,   -8.99999905,
#            -70.99999237,  -54.99999619],
#          [  43.00001144,  -56.99999619,  -14.99999905, ...,  -18.99999809,
#            -24.99999809,  -52.99999619],
#          ...,
#          [-116.99999237, -108.99999237, -102.99999237, ..., -100.99999237,
#           -100.99999237, -106.99999237],
#          [-114.99999237, -106.99999237, -100.99999237, ..., -100.99999237,
#           -106.99999237, -102.99999237],
#          [-108.99999237, -100.99999237, -102.99999237, ..., -108.99999237,
#           -106.99999237,  -94.99999237]]],
#
#
#        [[[ -54.99999619,  -58.99999619,  -54.99999619, ...,  -44.99999619,
#            -44.99999619,  -50.99999619],
#          [ -98.99999237,  -96.99999237,  -96.99999237, ...,  -94.99999237,
#            -84.99999237,  -52.99999619],
#          [-139.        , -139.        , -137.        , ..., -112.99999237,
#           -108.99999237,  -64.99999237],
#          ...,
#          [   5.00001478,    1.00001514,   -4.99999952, ...,    7.00001478,
#              5.00001478,    3.00001502],
#          [  21.00001335,    3.00001502,   -6.99999952, ...,    7.00001478,
#             13.00001431,   23.00001335],
#          [  17.00001335,    1.00001514,   -0.99999994, ...,   35.00001144,
#             35.00001144,   47.00001144]],
#
#         [[ -50.99999619,  -54.99999619,  -48.99999619, ...,  -30.99999809,
#            -34.99999619,  -40.99999619],
#          [ -88.99999237,  -88.99999237,  -86.99999237, ...,  -66.99999237,
#            -62.99999619,  -38.99999619],
#          [-110.99999237, -112.99999237, -110.99999237, ...,  -82.99999237,
#            -88.99999237,  -52.99999619],
#          ...,
#          [  -6.99999952,  -10.99999905,  -16.99999809, ...,   -8.99999905,
#            -14.99999905,  -18.99999809],
#          [   9.00001431,   -8.99999905,  -18.99999809, ...,  -16.99999809,
#            -12.99999905,   -2.99999976],
#          [   5.00001478,  -10.99999905,  -12.99999905, ...,    7.00001478,
#              5.00001478,   13.00001431]],
#
#         [[ -38.99999619,  -42.99999619,  -36.99999619, ...,  -24.99999809,
#            -22.99999809,  -24.99999809],
#          [ -80.99999237,  -80.99999237,  -78.99999237, ...,  -60.99999619,
#            -52.99999619,  -24.99999809],
#          [-108.99999237, -110.99999237, -108.99999237, ...,  -96.99999237,
#            -94.99999237,  -52.99999619],
#          ...,
#          [   1.00001514,   -2.99999976,   -8.99999905, ...,  -18.99999809,
#            -20.99999809,  -24.99999809],
#          [  17.00001335,   -0.99999994,  -10.99999905, ...,  -18.99999809,
#            -12.99999905,   -2.99999976],
#          [  13.00001431,   -2.99999976,   -4.99999952, ...,    9.00001431,
#              9.00001431,   17.00001335]]],
#
#
#        ...,
#        [[[ -90.99999237,  -96.99999237,  -96.99999237, ...,  -44.99999619,
#            -50.99999619,  -16.99999809],
#          [ -94.99999237,  -88.99999237,  -86.99999237, ...,  -64.99999237,
#            -26.99999809,   13.00001431],
#          [ -82.99999237,  -78.99999237, -100.99999237, ...,  -36.99999619,
#            -30.99999809,    1.00001514],
#          ...,
#          [   1.00001514,  -12.99999905,  -54.99999619, ...,  -34.99999619,
#            -78.99999237,  -98.99999237],
#          [  49.00001144,   23.00001335,    1.00001514, ..., -100.99999237,
#           -112.99999237,  -94.99999237],
#          [  23.00001335,    7.00001478,   41.00001144, ...,  -98.99999237,
#           -124.99999237,  -88.99999237]],
#
#         [[-126.99999237, -126.99999237, -122.99999237, ...,  -70.99999237,
#            -70.99999237,  -24.99999809],
#          [-131.        , -110.99999237,  -96.99999237, ...,  -72.99999237,
#            -28.99999809,   19.00001335],
#          [-122.99999237, -106.99999237, -116.99999237, ...,  -54.99999619,
#            -46.99999619,  -12.99999905],
#          ...,
#          [  13.00001431,    3.00001502,  -32.99999619, ...,  -18.99999809,
#            -66.99999237,  -90.99999237],
#          [  49.00001144,   29.00001335,   15.00001431, ...,  -86.99999237,
#            -98.99999237,  -80.99999237],
#          [  27.00001335,   19.00001335,   59.00001144, ...,  -96.99999237,
#           -124.99999237,  -80.99999237]],
#
#         [[-181.        , -191.        , -185.        , ..., -110.99999237,
#           -112.99999237,  -72.99999237],
#          [-189.        , -183.        , -169.        , ..., -122.99999237,
#            -80.99999237,  -36.99999619],
#          [-177.        , -171.        , -183.        , ..., -104.99999237,
#            -96.99999237,  -64.99999237],
#          ...,
#          [ -86.99999237,  -94.99999237, -153.        , ..., -124.99999237,
#           -161.        , -177.        ],
#          [ -26.99999809,  -52.99999619,  -86.99999237, ..., -185.        ,
#           -183.        , -165.        ],
#          [ -56.99999619,  -78.99999237,  -52.99999619, ..., -175.        ,
#           -191.        , -163.        ]]],
#
#
#        [[[-112.99999237,  -78.99999237,  -90.99999237, ..., -197.        ,
#           -199.        , -201.        ],
#          [-187.        , -179.        , -179.        , ..., -199.        ,
#           -199.        , -199.        ],
#          [-199.        , -199.        , -195.        , ..., -197.        ,
#           -199.        , -201.        ],
#          ...,
#          [ -92.99999237, -106.99999237, -118.99999237, ...,  -78.99999237,
#            -98.99999237,  -98.99999237],
#          [ -86.99999237, -100.99999237, -114.99999237, ...,  -58.99999619,
#            -74.99999237,  -86.99999237],
#          [ -82.99999237,  -86.99999237,  -92.99999237, ...,  -58.99999619,
#            -68.99999237,  -84.99999237]],
#
#         [[-102.99999237,  -68.99999237,  -80.99999237, ..., -185.        ,
#           -189.        , -191.        ],
#          [-175.        , -169.        , -169.        , ..., -187.        ,
#           -189.        , -189.        ],
#          [-189.        , -189.        , -185.        , ..., -185.        ,
#           -189.        , -191.        ],
#          ...,
#          [ -80.99999237,  -88.99999237,  -94.99999237, ...,  -64.99999237,
#            -76.99999237,  -74.99999237],
#          [ -84.99999237,  -90.99999237,  -98.99999237, ...,  -48.99999619,
#            -58.99999619,  -70.99999237],
#          [ -86.99999237,  -86.99999237,  -84.99999237, ...,  -52.99999619,
#            -60.99999619,  -76.99999237]],
#
#         [[ -90.99999237,  -56.99999619,  -68.99999237, ..., -173.        ,
#           -179.        , -179.        ],
#          [-163.        , -157.        , -157.        , ..., -173.        ,
#           -177.        , -177.        ],
#          [-177.        , -177.        , -173.        , ..., -171.        ,
#           -177.        , -179.        ],
#          ...,
#          [-114.99999237, -122.99999237, -131.        , ..., -110.99999237,
#           -122.99999237, -124.99999237],
#          [-120.99999237, -129.        , -137.        , ...,  -92.99999237,
#           -104.99999237, -116.99999237],
#          [-126.99999237, -126.99999237, -129.        , ...,  -94.99999237,
#           -102.99999237, -120.99999237]]],
#
#
#        [[[ 237.        ,  247.        ,  249.        , ...,   55.00001144,
#             63.00001144,   65.00000763],
#          [ 245.        ,  255.        ,  255.        , ...,   31.00001335,
#             33.00001144,   41.00001144],
#          [ 245.        ,  253.        ,  253.        , ...,   25.00001335,
#             27.00001335,   41.00001144],
#          ...,
#          [  -2.99999976,   -8.99999905,   -4.99999952, ..., -106.99999237,
#           -102.99999237, -114.99999237],
#          [ -16.99999809,  -14.99999905,  -10.99999905, ..., -110.99999237,
#           -112.99999237, -126.99999237],
#          [   9.00001431,   17.00001335,   27.00001335, ...,  -62.99999619,
#            -64.99999237,  -76.99999237]],
#
#         [[ 249.        ,  247.        ,  247.        , ...,  133.        ,
#            131.        ,  133.        ],
#          [ 251.        ,  255.        ,  255.        , ...,  121.00000763,
#            123.00000763,  125.00000763],
#          [ 247.        ,  251.        ,  251.        , ...,  125.00000763,
#            131.        ,  137.        ],
#          ...,
#          [ -10.99999905,  -14.99999905,  -14.99999905, ..., -143.        ,
#           -145.        , -151.        ],
#          [ -24.99999809,  -20.99999809,  -16.99999809, ..., -145.        ,
#           -151.        , -161.        ],
#          [   3.00001502,   13.00001431,   21.00001335, ...,  -90.99999237,
#            -92.99999237, -100.99999237]],
#
#         [[ 251.        ,  247.        ,  245.        , ...,  235.        ,
#            235.        ,  225.        ],
#          [ 255.        ,  251.        ,  251.        , ...,  249.        ,
#            251.        ,  233.        ],
#          [ 249.        ,  245.        ,  247.        , ...,  247.        ,
#            251.        ,  239.        ],
#          ...,
#          [ -54.99999619,  -72.99999237,  -62.99999619, ..., -175.        ,
#           -175.        , -179.        ],
#          [ -60.99999619,  -66.99999237,  -56.99999619, ..., -179.        ,
#           -183.        , -189.        ],
#          [ -24.99999809,  -18.99999809,   -4.99999952, ..., -118.99999237,
#           -120.99999237, -126.99999237]]]], dtype=float32)
