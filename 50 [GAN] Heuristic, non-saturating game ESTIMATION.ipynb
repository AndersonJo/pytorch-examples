# %%
# %pylab inline
import numpy as np
import torch

from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.autograd import Variable
from torch.utils.data import dataloader

from torchvision import transforms
from torchvision.datasets import MNIST

from graphviz import Digraph
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Configuration

# %%
BATCH_SIZE = 32

# %% [markdown]
# ## Data (MNIST)

# %%
train = MNIST('./data', train=True, download=True, transform=transforms.Compose([
    transforms.ToTensor(), # ToTensor does min-max normalization. 
]), )

test = MNIST('./data', train=False, download=True, transform=transforms.Compose([
    transforms.ToTensor(), # ToTensor does min-max normalization. 
    
]), )

# Create DataLoader
dataloader_args = dict(shuffle=True, batch_size=BATCH_SIZE ,num_workers=1, pin_memory=True)
train_loader = dataloader.DataLoader(train, **dataloader_args)
test_loader = dataloader.DataLoader(test, **dataloader_args)

# %% [markdown]
# ## Model Discriminator
#
# ### Discriminator
#
# * $ x_i \sim P_{\rm data} $ (즉 true data distribution) 에서 왔다면 1
# * $ x_i = G(z) $ 이때 $ z \sim p_{\rm generator} $ (generators' distribution)에서 왔다면 0
#
# 즉 Discriminator는 "이 사진이 진짜냐? (가짜가 아니고)" 라고 질문하는 것

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.fc1 = nn.Linear(784, 576)
        self.fc2 = nn.Linear(576, 400)
        self.fc3 = nn.Linear(400, 256)
        self.fc4 = nn.Linear(256, 1)
        
        self.bc1 = nn.BatchNorm1d(576)
        self.bc2 = nn.BatchNorm1d(400)
        self.bc3 = nn.BatchNorm1d(256)
                
    def forward(self, x):
        x = x.view((-1, 784))
        h = self.fc1(x)
        h = self.bc1(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.5, training=self.training)
        
        h = self.fc2(h)
        h = self.bc2(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.3, training=self.training)
        
        h = self.fc3(h)
        h = self.bc3(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.2, training=self.training)
        
        h = self.fc4(h)
        out = F.sigmoid(h)
        return out

D = Discriminator()
print(D.cuda()) # CUDA!
d_optimizer = optim.Adam(D.parameters(), lr=0.001)
# Out:
# Discriminator (
#   (fc1): Linear (784 -> 576)
#   (fc2): Linear (576 -> 400)
#   (fc3): Linear (400 -> 256)
#   (fc4): Linear (256 -> 1)
#   (bc1): BatchNorm1d(576, eps=1e-05, momentum=0.1, affine=True)
#   (bc2): BatchNorm1d(400, eps=1e-05, momentum=0.1, affine=True)
#   (bc3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True)
# )

# %% [markdown]
# ### Generator

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        
        self.fc1 = nn.Linear(100, 196)
        self.fc2 = nn.Linear(196, 289)
        self.fc3 = nn.Linear(289, 361)
        self.fc4 = nn.Linear(361, 529)
        self.fc5 = nn.Linear(529, 784)
        
        self.bc1 = nn.BatchNorm1d(196)
        self.bc2 = nn.BatchNorm1d(289)
        self.bc3 = nn.BatchNorm1d(361)
        self.bc4 = nn.BatchNorm1d(529)
    
    def forward(self, x):
        h = self.fc1(x)
        h = self.bc1(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.5, training=self.training)
        
        h = self.fc2(h)
        h = self.bc2(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.3, training=self.training)
        
        h = self.fc3(h)
        h = self.bc3(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.2, training=self.training)
        
        h = self.fc4(h)
        h = self.bc4(h)
        h = F.relu(h)
        h = F.dropout(h, p=0.2, training=self.training)
        
        h = self.fc5(h)
        out = F.sigmoid(h)
        return out

G = Generator()
print(G.cuda())
g_optimizer = optim.Adam(G.parameters(), lr=0.001)
# Out:
# Generator (
#   (fc1): Linear (100 -> 196)
#   (fc2): Linear (196 -> 289)
#   (fc3): Linear (289 -> 361)
#   (fc4): Linear (361 -> 529)
#   (fc5): Linear (529 -> 784)
#   (bc1): BatchNorm1d(196, eps=1e-05, momentum=0.1, affine=True)
#   (bc2): BatchNorm1d(289, eps=1e-05, momentum=0.1, affine=True)
#   (bc3): BatchNorm1d(361, eps=1e-05, momentum=0.1, affine=True)
#   (bc4): BatchNorm1d(529, eps=1e-05, momentum=0.1, affine=True)
# )

# %% [markdown]
# ## Visualization

# %%
def make_dot(var):
    node_attr = dict(style='filled',
                     shape='box',
                     align='left',
                     fontsize='12',
                     ranksep='0.1',
                     height='0.2')
    dot = Digraph(node_attr=node_attr, graph_attr=dict(size="12,12"))
    seen = set()

    def add_nodes(var):
        if var not in seen:
            if isinstance(var, Variable):
                value = '('+(', ').join(['%d'% v for v in var.size()])+')'
                dot.node(str(id(var)), str(value), fillcolor='lightblue')
            else:
                dot.node(str(id(var)), str(type(var).__name__))
            seen.add(var)
            if hasattr(var, 'previous_functions'):
                for u in var.previous_functions:
                    dot.edge(str(id(u[0])), str(id(var)))
                    add_nodes(u[0])
    add_nodes(var.creator)
    return dot

# %%
real_image = train[0][0].cuda()
real_image = Variable(real_image)
make_dot(D(real_image))

# %%
fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
images = G(fake_distributions).view((-1, 28, 28))
make_dot(images)

# %% [markdown]
# ## Train
#
# * $ 1 $ : real images
# * $ 0 $ : fake images

# %%
N_EPOCH = 100

real_y = Variable(torch.ones((BATCH_SIZE, 1)).cuda())
fake_y = Variable(torch.zeros((BATCH_SIZE, 1)).cuda())
loss_f = nn.BCELoss()

d_real_losses = list()
d_fake_losses = list()
g_losses = list()
divergences = list()

# %%
# Train Discriminator with Generator not being trained
# 먼저 Discriminator를 학습시킵니다.
# 이때 real image와 fake이미지 두개의 데이터를 사용하여 학습합니다. 
# Discriminator를 학습시킬때는 Generator는 학습시키면 안됩니다.

for epoch in range(N_EPOCH):
    _d_real_losses = list()
    _d_fake_losses = list()
    _g_losses = list()
    _divergences = list()
    
    for step, (real_images, _) in enumerate(train_loader):
        real_images = Variable(real_images.cuda())

        # Init D
        d_optimizer.zero_grad()

        ###############################################
        # Train D with real images
        ###############################################
        y_real_pred = D(real_images)
        d_real_loss = loss_f(y_real_pred, real_y)
        d_real_loss.backward()
        d_optimizer.step()
        
        # Visualization
        _d_real_losses.append(d_real_loss.data[0])

        ###############################################
        # Train D with fake images but do not train G
        ###############################################
        fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
        fake_images = G(fake_distributions).detach()
        y_fake_pred = D(fake_images)
        d_fake_loss = loss_f(y_fake_pred, fake_y)
        d_fake_loss.backward()
        d_optimizer.step()
        
        # Visualization
        _d_fake_losses.append(d_fake_loss.data[0])
        _divergences.append(torch.mean(y_real_pred/(y_real_pred+y_fake_pred)).data.cpu()[0])
        
        ###############################################
        # Train G with fake images but do not train G
        ###############################################
        g_optimizer.zero_grad()
        
        fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
        fake_images = G(fake_distributions)
        y_pred = D(fake_images)
        g_loss = loss_f(y_pred, real_y)
        g_loss.backward()
        g_optimizer.step()
        
        # Visualization
        _g_losses.append(g_loss.data.cpu().numpy()[0])
        
        if step % 200 == 0:
            _d_real_losses = np.array(_d_real_losses)
            _d_fake_losses = np.array(_d_fake_losses)
            _g_losses = np.array(_g_losses)
            _divergences = np.array(_divergences)
            
            d_real_losses.append(_d_real_losses.mean())
            d_fake_losses.append(_d_fake_losses.mean())
            g_losses.append(_g_losses.mean())
            divergences.append(_divergences.mean())
            
            print(f'\rEpoch:[{epoch} | {step}] ',
                  'Divergence: {:.4} |'.format(_divergences.mean()),
                  'D_real_loss: {:.4} |'.format(_d_real_losses.mean()),
                  'D_fake_loss: {:.4} |'.format(_d_fake_losses.mean()), 
                  'G_loss:{:.4}'.format(_g_losses.mean()), end='') 
            
            _d_real_losses = list()
            _d_fake_losses = list()
            _g_losses = list()
            _divergences = list()
            
    print()
# Out:
# Epoch:[0 | 1800]  Divergence: 0.9396 | D_real_loss: 0.05361 | D_fake_loss: 0.1174 | G_loss:4.846
# Epoch:[1 | 1800]  Divergence: 0.9454 | D_real_loss: 0.05828 | D_fake_loss: 0.1171 | G_loss:5.566
# Epoch:[2 | 1800]  Divergence: 0.9571 | D_real_loss: 0.05025 | D_fake_loss: 0.08068 | G_loss:5.477
# Epoch:[3 | 1800]  Divergence: 0.9576 | D_real_loss: 0.04755 | D_fake_loss: 0.09753 | G_loss:6.149
# Epoch:[4 | 1800]  Divergence: 0.9573 | D_real_loss: 0.05156 | D_fake_loss: 0.1118 | G_loss:6.0166
# Epoch:[5 | 1800]  Divergence: 0.9444 | D_real_loss: 0.07976 | D_fake_loss: 0.1392 | G_loss:5.6386
# Epoch:[6 | 1800]  Divergence: 0.9402 | D_real_loss: 0.05979 | D_fake_loss: 0.1762 | G_loss:5.4463
# Epoch:[7 | 1800]  Divergence: 0.9428 | D_real_loss: 0.067 | D_fake_loss: 0.1578 | G_loss:5.93194
# Epoch:[8 | 1800]  Divergence: 0.9619 | D_real_loss: 0.04387 | D_fake_loss: 0.07578 | G_loss:5.908
# Epoch:[9 | 1800]  Divergence: 0.9537 | D_real_loss: 0.05556 | D_fake_loss: 0.08855 | G_loss:5.679
# Epoch:[10 | 1800]  Divergence: 0.971 | D_real_loss: 0.03865 | D_fake_loss: 0.08629 | G_loss:7.8118
# Epoch:[11 | 1800]  Divergence: 0.9659 | D_real_loss: 0.05206 | D_fake_loss: 0.08969 | G_loss:7.372
# Epoch:[12 | 1800]  Divergence: 0.9899 | D_real_loss: 0.008279 | D_fake_loss: 0.01811 | G_loss:8.552
# Epoch:[13 | 1800]  Divergence: 0.9768 | D_real_loss: 0.03474 | D_fake_loss: 0.06218 | G_loss:8.251
# Epoch:[14 | 1800]  Divergence: 0.9805 | D_real_loss: 0.03714 | D_fake_loss: 0.06122 | G_loss:10.11
# Epoch:[15 | 1800]  Divergence: 0.9698 | D_real_loss: 0.03219 | D_fake_loss: 0.07535 | G_loss:7.283
# Epoch:[16 | 1800]  Divergence: 0.971 | D_real_loss: 0.04175 | D_fake_loss: 0.08085 | G_loss:7.9587
# Epoch:[17 | 1800]  Divergence: 0.9857 | D_real_loss: 0.01477 | D_fake_loss: 0.04308 | G_loss:9.531
# Epoch:[18 | 1800]  Divergence: 0.9884 | D_real_loss: 0.008966 | D_fake_loss: 0.01994 | G_loss:7.623
# Epoch:[19 | 1800]  Divergence: 0.9888 | D_real_loss: 0.01707 | D_fake_loss: 0.02276 | G_loss:9.4688
# Epoch:[20 | 1800]  Divergence: 0.9847 | D_real_loss: 0.02559 | D_fake_loss: 0.05278 | G_loss:8.846
# Epoch:[21 | 1800]  Divergence: 0.9638 | D_real_loss: 0.05771 | D_fake_loss: 0.1265 | G_loss:7.3316
# Epoch:[22 | 1800]  Divergence: 0.9455 | D_real_loss: 0.08349 | D_fake_loss: 0.1412 | G_loss:5.594
# Epoch:[23 | 1800]  Divergence: 0.933 | D_real_loss: 0.08519 | D_fake_loss: 0.1841 | G_loss:5.1939
# Epoch:[24 | 1800]  Divergence: 0.921 | D_real_loss: 0.1034 | D_fake_loss: 0.2112 | G_loss:4.65229
# Epoch:[25 | 1800]  Divergence: 0.9346 | D_real_loss: 0.08048 | D_fake_loss: 0.1845 | G_loss:5.285
# Epoch:[26 | 1800]  Divergence: 0.93 | D_real_loss: 0.08016 | D_fake_loss: 0.1717 | G_loss:4.92661
# Epoch:[27 | 1800]  Divergence: 0.9152 | D_real_loss: 0.1089 | D_fake_loss: 0.234 | G_loss:4.4594
# Epoch:[28 | 1800]  Divergence: 0.9129 | D_real_loss: 0.1164 | D_fake_loss: 0.2015 | G_loss:4.307
# Epoch:[29 | 1800]  Divergence: 0.8908 | D_real_loss: 0.1526 | D_fake_loss: 0.3092 | G_loss:3.455
# Epoch:[30 | 1800]  Divergence: 0.8972 | D_real_loss: 0.1245 | D_fake_loss: 0.2717 | G_loss:3.695
# Epoch:[31 | 1800]  Divergence: 0.8958 | D_real_loss: 0.1259 | D_fake_loss: 0.2551 | G_loss:3.9029
# Epoch:[32 | 1800]  Divergence: 0.8944 | D_real_loss: 0.1126 | D_fake_loss: 0.2598 | G_loss:3.785
# Epoch:[33 | 1800]  Divergence: 0.8923 | D_real_loss: 0.1263 | D_fake_loss: 0.2733 | G_loss:4.0452
# Epoch:[34 | 1800]  Divergence: 0.9026 | D_real_loss: 0.09629 | D_fake_loss: 0.2284 | G_loss:3.678
# Epoch:[35 | 1800]  Divergence: 0.8879 | D_real_loss: 0.1261 | D_fake_loss: 0.2421 | G_loss:3.3887
# Epoch:[36 | 1800]  Divergence: 0.8769 | D_real_loss: 0.1566 | D_fake_loss: 0.2831 | G_loss:3.456
# Epoch:[37 | 1800]  Divergence: 0.8712 | D_real_loss: 0.1592 | D_fake_loss: 0.2968 | G_loss:3.156
# Epoch:[38 | 1800]  Divergence: 0.8809 | D_real_loss: 0.1381 | D_fake_loss: 0.3009 | G_loss:3.452
# Epoch:[39 | 1800]  Divergence: 0.8745 | D_real_loss: 0.1486 | D_fake_loss: 0.299 | G_loss:3.6023
# Epoch:[40 | 1800]  Divergence: 0.8856 | D_real_loss: 0.1136 | D_fake_loss: 0.274 | G_loss:3.3353
# Epoch:[41 | 1800]  Divergence: 0.859 | D_real_loss: 0.1548 | D_fake_loss: 0.3325 | G_loss:3.0679
# Epoch:[42 | 1800]  Divergence: 0.8531 | D_real_loss: 0.1604 | D_fake_loss: 0.3463 | G_loss:2.941
# Epoch:[43 | 1800]  Divergence: 0.8586 | D_real_loss: 0.1419 | D_fake_loss: 0.3234 | G_loss:3.219
# Epoch:[44 | 1800]  Divergence: 0.866 | D_real_loss: 0.1349 | D_fake_loss: 0.3013 | G_loss:3.1382
# Epoch:[45 | 1800]  Divergence: 0.8512 | D_real_loss: 0.1492 | D_fake_loss: 0.3228 | G_loss:2.957
# Epoch:[46 | 1800]  Divergence: 0.8631 | D_real_loss: 0.1406 | D_fake_loss: 0.3065 | G_loss:2.832
# Epoch:[47 | 1800]  Divergence: 0.8465 | D_real_loss: 0.1543 | D_fake_loss: 0.4103 | G_loss:2.766
# Epoch:[48 | 1800]  Divergence: 0.8313 | D_real_loss: 0.1713 | D_fake_loss: 0.4004 | G_loss:2.865
# Epoch:[49 | 1800]  Divergence: 0.8326 | D_real_loss: 0.1724 | D_fake_loss: 0.3875 | G_loss:2.672
# Epoch:[50 | 1800]  Divergence: 0.8331 | D_real_loss: 0.1783 | D_fake_loss: 0.3736 | G_loss:2.355
# Epoch:[51 | 1800]  Divergence: 0.8331 | D_real_loss: 0.176 | D_fake_loss: 0.3963 | G_loss:2.6283
# Epoch:[52 | 1800]  Divergence: 0.832 | D_real_loss: 0.1496 | D_fake_loss: 0.388 | G_loss:2.40586
# Epoch:[53 | 1800]  Divergence: 0.7958 | D_real_loss: 0.2087 | D_fake_loss: 0.4852 | G_loss:2.495
# Epoch:[54 | 1800]  Divergence: 0.824 | D_real_loss: 0.1791 | D_fake_loss: 0.3842 | G_loss:2.4986
# Epoch:[55 | 1800]  Divergence: 0.8078 | D_real_loss: 0.1902 | D_fake_loss: 0.5117 | G_loss:2.381
# Epoch:[56 | 1800]  Divergence: 0.8391 | D_real_loss: 0.1657 | D_fake_loss: 0.3591 | G_loss:2.597
# Epoch:[57 | 1800]  Divergence: 0.804 | D_real_loss: 0.2094 | D_fake_loss: 0.4623 | G_loss:2.2804
# Epoch:[58 | 1800]  Divergence: 0.8236 | D_real_loss: 0.1719 | D_fake_loss: 0.407 | G_loss:2.3271
# Epoch:[59 | 1800]  Divergence: 0.8266 | D_real_loss: 0.1972 | D_fake_loss: 0.397 | G_loss:2.6708
# Epoch:[60 | 1800]  Divergence: 0.8246 | D_real_loss: 0.1816 | D_fake_loss: 0.398 | G_loss:2.3229
# Epoch:[61 | 1800]  Divergence: 0.847 | D_real_loss: 0.1557 | D_fake_loss: 0.3644 | G_loss:2.9877
# Epoch:[62 | 1800]  Divergence: 0.8162 | D_real_loss: 0.1864 | D_fake_loss: 0.4195 | G_loss:2.324
# Epoch:[63 | 1800]  Divergence: 0.8152 | D_real_loss: 0.1805 | D_fake_loss: 0.4207 | G_loss:2.365
# Epoch:[64 | 1800]  Divergence: 0.8176 | D_real_loss: 0.1777 | D_fake_loss: 0.4353 | G_loss:2.419
# Epoch:[65 | 1800]  Divergence: 0.8022 | D_real_loss: 0.2071 | D_fake_loss: 0.4403 | G_loss:2.212
# Epoch:[66 | 1800]  Divergence: 0.8125 | D_real_loss: 0.1937 | D_fake_loss: 0.4403 | G_loss:2.358
# Epoch:[67 | 1800]  Divergence: 0.8208 | D_real_loss: 0.1729 | D_fake_loss: 0.4041 | G_loss:2.389
# Epoch:[68 | 1800]  Divergence: 0.8081 | D_real_loss: 0.1957 | D_fake_loss: 0.456 | G_loss:2.2867
# Epoch:[69 | 1800]  Divergence: 0.8143 | D_real_loss: 0.1845 | D_fake_loss: 0.417 | G_loss:2.3884
# Epoch:[70 | 1800]  Divergence: 0.8169 | D_real_loss: 0.1811 | D_fake_loss: 0.3943 | G_loss:2.407
# Epoch:[71 | 1800]  Divergence: 0.81 | D_real_loss: 0.1886 | D_fake_loss: 0.4372 | G_loss:2.35515
# Epoch:[72 | 1800]  Divergence: 0.8263 | D_real_loss: 0.1724 | D_fake_loss: 0.3983 | G_loss:2.518
# Epoch:[73 | 1800]  Divergence: 0.8315 | D_real_loss: 0.1627 | D_fake_loss: 0.3772 | G_loss:2.314
# Epoch:[74 | 1800]  Divergence: 0.8043 | D_real_loss: 0.1938 | D_fake_loss: 0.4621 | G_loss:2.274
# Epoch:[75 | 1800]  Divergence: 0.8137 | D_real_loss: 0.1714 | D_fake_loss: 0.4151 | G_loss:2.272
# Epoch:[76 | 1800]  Divergence: 0.7939 | D_real_loss: 0.2224 | D_fake_loss: 0.4705 | G_loss:2.283
# Epoch:[77 | 1800]  Divergence: 0.8131 | D_real_loss: 0.1975 | D_fake_loss: 0.4109 | G_loss:2.466
# Epoch:[78 | 1800]  Divergence: 0.8155 | D_real_loss: 0.1795 | D_fake_loss: 0.4499 | G_loss:2.188
# Epoch:[79 | 1800]  Divergence: 0.8102 | D_real_loss: 0.1965 | D_fake_loss: 0.4164 | G_loss:2.452
# Epoch:[80 | 1800]  Divergence: 0.8101 | D_real_loss: 0.1881 | D_fake_loss: 0.4684 | G_loss:2.506
# Epoch:[81 | 1800]  Divergence: 0.8167 | D_real_loss: 0.1968 | D_fake_loss: 0.4176 | G_loss:2.634
# Epoch:[82 | 1800]  Divergence: 0.8187 | D_real_loss: 0.1994 | D_fake_loss: 0.3897 | G_loss:2.384
# Epoch:[83 | 1800]  Divergence: 0.8078 | D_real_loss: 0.1829 | D_fake_loss: 0.4797 | G_loss:2.321
# Epoch:[84 | 1800]  Divergence: 0.8303 | D_real_loss: 0.1513 | D_fake_loss: 0.3722 | G_loss:2.575
# Epoch:[85 | 1800]  Divergence: 0.8295 | D_real_loss: 0.1525 | D_fake_loss: 0.3777 | G_loss:2.392
# Epoch:[86 | 1800]  Divergence: 0.8091 | D_real_loss: 0.1992 | D_fake_loss: 0.4703 | G_loss:2.164
# Epoch:[87 | 1800]  Divergence: 0.8041 | D_real_loss: 0.1967 | D_fake_loss: 0.4878 | G_loss:2.065
# Epoch:[88 | 1800]  Divergence: 0.8217 | D_real_loss: 0.1901 | D_fake_loss: 0.4287 | G_loss:2.348
# Epoch:[89 | 1800]  Divergence: 0.8275 | D_real_loss: 0.174 | D_fake_loss: 0.3827 | G_loss:2.4575
# Epoch:[90 | 1800]  Divergence: 0.8203 | D_real_loss: 0.1886 | D_fake_loss: 0.3822 | G_loss:2.574
# Epoch:[91 | 1800]  Divergence: 0.8082 | D_real_loss: 0.1988 | D_fake_loss: 0.456 | G_loss:2.1289
# Epoch:[92 | 1800]  Divergence: 0.8386 | D_real_loss: 0.1456 | D_fake_loss: 0.3473 | G_loss:2.561
# Epoch:[93 | 1800]  Divergence: 0.8204 | D_real_loss: 0.1779 | D_fake_loss: 0.4169 | G_loss:2.455
# Epoch:[94 | 1800]  Divergence: 0.8146 | D_real_loss: 0.1904 | D_fake_loss: 0.4487 | G_loss:2.466
# Epoch:[95 | 1800]  Divergence: 0.7984 | D_real_loss: 0.1955 | D_fake_loss: 0.4537 | G_loss:2.105
# Epoch:[96 | 1800]  Divergence: 0.8235 | D_real_loss: 0.1786 | D_fake_loss: 0.4025 | G_loss:2.542
# Epoch:[97 | 1800]  Divergence: 0.8282 | D_real_loss: 0.1695 | D_fake_loss: 0.3916 | G_loss:2.303
# Epoch:[98 | 1800]  Divergence: 0.781 | D_real_loss: 0.2301 | D_fake_loss: 0.4953 | G_loss:1.9188
# Epoch:[99 | 1800]  Divergence: 0.8065 | D_real_loss: 0.2196 | D_fake_loss: 0.4348 | G_loss:2.339

# %% [markdown]
# ## Loss Visualization

# %%
plot(d_real_losses, label='D(x) Loss')
plot(d_fake_losses, label='D(G(z)) Loss')
plot(g_losses, label='G(z) loss')
plot(divergences, label='divergences')

grid()
legend()
figsize(16, 6)

# %%
fake_distributions = Variable(torch.randn((BATCH_SIZE, 100)).cuda())
images = G(fake_distributions).view((-1, 28, 28)).data.cpu().numpy()

images[0]
imshow(images[0], cmap=cm.gray_r)

fig, subplots = pylab.subplots(4, 7) # subplots(y축, x축 갯수)

idx = 0
for _subs in subplots:
    for subplot in _subs:
        d = images[idx]
        subplot.get_xaxis().set_visible(False)
        subplot.get_yaxis().set_visible(False)
        subplot.imshow(d, cmap=cm.gray_r)
        idx += 1
